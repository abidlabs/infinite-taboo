# %%
import json
import nltk

# %%
nltk.download('brown')
nltk.download('wordnet')
from nltk import FreqDist
from nltk.corpus import brown
frequency_list = FreqDist(i.lower() for i in brown.words())
# Out:
# [nltk_data] Downloading package brown to
# [nltk_data]     C:\Users\islam\AppData\Roaming\nltk_data...
# [nltk_data]   Package brown is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\islam\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
frequency_list['territories']
# Out:
# 9

# %%
with open('raw_data/words.json') as f:
    data = json.load(f)

# %%
import csv
with open('out_data/data1.csv', 'w', newline='') as file:
    writer = csv.writer(file)    
    for sample in data:
        key_word =  sample['word'] 
        taboo_words = ','.join(sample['prohibited'])
        writer.writerow([key_word, taboo_words])

# %%
# Out:
# "Canada"
# "maple,ontario,nations,territories,provinces,vancouver,toronto,french,quebec""
# "Communism"
# "lenin,karl marx,society,marxist,revolution,soviet,leninism,socialism,party,marxism""
# "Our Lady of Guadalupe"
# "spanish,catholic,mary,image,mexico,virgin""
# "Sun"
# "temperature,surface,core,energy,light,mass,magnetic,earth,solar""
# "Sugar"
# "carbohydrates,blood,disease,fructose,refined,sugarcane,sucrose,glucose""
# "Elephant"
# "matriarch,males,animals,african,trunk,species,asian""
# "Yogurt"
# "bacteria,strained,fat,fermented,fruit,cheese,dairy,turkish,milk""
# "The Holocaust"
# "hitler,extermination,victims,camp,poland,auschwitz,german,nazi,jewish""
# "Rosa Parks"
# "white,alabama,boycott,black,detroit,civil rights,montgomery,bus""
# "Sherlock Holmes"
# "case,fictional,detective,arthur conan doyle,stories,adventure,watson""
# "Ludwig van Beethoven"
# "sonatas,composers,vienna,symphony,piano,musician""
# "Muhammad Ali"
# "round,ring,joe frazier,win,cassius clay,boxing,heavyweight,fight""
# "Nicolas Cage"
# "performance,national treasure,role,actor,male,film""
# "System of a Down"
# "serj,groups,toxicity,odadjian,musical,malakian,tankian,rock,metal,album,band""
# "Plato"
# "ancient,works,forms,republic,oxford,philosophy,greek,dialogues,socrates""
# "Eminem"
# "hip hop,kim,rap,marshall mathers,song,shady,album""
# "Paris"
# "capital,eiffel tower,french,city,france""
# "Nelson Mandela"
# "trial,order,klerk,johannesburg,president,south africa,anc""
# "Plague"
# "spread,fever,flea,infection,black,death,disease,bubonic""
# "Jacqueline Kennedy Onassis"
# "new york,white,jackie,house,bouvier,lady,john""
# "Benedict Cumberbatch"
# "television,film,sherlock,award,actor,theatre,bbc,radio""
# "Hanukkah"
# "candles,religious,temple,jews,menorah,holidays,lights,hebrew,jewish""
# "Google logo"
# "animation,search,anniversary,favicon,interactive,birthday,doodle""
# "The Beatles"
# "artists,rock,ringo starr,music,songs,george harrison,album,band,paul mccartney,john lennon""
# "Bermuda Triangle"
# "florida,incidents,mystery,atlantic,ships,aircraft,disappearance,area,flight""
# "Moon"
# "mission,waxing,space,side,waning,orbit,full,earth,lunar""
# "Maslow's hierarchy of needs"
# "psychology,human,levels,theory,physiological,safety,actualization,self esteem""
# "The Walking Dead"
# "main,survivors,walkers,episode,darabont,amc,television,governor,rick,zombies""
# "Natalie Portman"
# "black swan,award,harvard,film,descent,actress,israeli,jewish""
# "Ethiopia"
# "health,africa,world,emperor,government,population,country,running,addis""
# "Recipe"
# "prepare,ingredients,culinary,dish,cookbook,food,cooking""
# "Backslash"
# "characters,code,line,path,punctuation,ascii,character,mark""
# "Haiku"
# "poets,verse,syllable,poetry,hokku,japanese""
# "South Korea"
# "japan,country,republic,relations,north,seoul""
# "The Simpsons"
# "marge,family,homer,animated,fox,characters,lisa,episode,series,bart,television,show""
# "Edward Snowden"
# "government,intelligence,hong kong,russia,surveillance,asylum,nsa""
# "Albert Einstein"
# "mechanics,light,motion,energy,genius,quantum,physics,relativity,theory""
# "Turkey"
# "eastern,europe,country,republic,istanbul,anatolia,ottoman,empire""
# "Lana Del Rey"
# "video,video games,singer,born to die,album,lizzy grant""
# "50 Cent"
# "song,rapper,g unit,album,game,curtis jackson""
# "James Bond"
# "film,casino royale,girls,series,novel,action,novels,fleming""
# "Reindeer"
# "donder,christmas,donner,nosed,red,sleigh,blitzen,rudolph""
# "Heath Ledger"
# "joker,death,critics,australian,film,award,actor""
# "Ellen DeGeneres"
# "comedy,talk show,voice,lgbt,actresses,american,emmy,writers,awards,funny""
# "Margaret Thatcher"
# "united kingdom,leader,government,labour,election,party,conservative,minister,prime""
# "Maryland"
# "chesapeake bay,city,virginia,washington DC,state,baltimore""
# "Rice"
# "paddy,irrigation,farmers,crop,china,cultivation,water,food,grain""
# "Norway"
# "europe,union,denmark,country,oslo,sweden""
# "The Hobbit"
# "journey,new zealand,rings,lord,guillermo del toro,bilbo,tolkien,peter jackson""
# "Ian McKellen"
# "royal,london,male,nominated,theatre,actor,award""
# "Bruce Lee"
# "dragon,chinese,fighting,hong kong,martial arts""
# "Zeus"
# "mythology,bolt,mount,oracle,cronus,sky,god,hera,greek,gods""
# "Air conditioning"
# "systems,room,unit,energy,engineering,technology,cooling,heat""
# "Charlize Theron"
# "female,film,south african,movie,award,actress""
# "Cleopatra"
# "rome,octavian,alexandria,egyptian,roman,mark antony,caesar,ptolemy""
# "NFL"
# "players,bowl,draft,conference,game,team,season,teams""
# "Xbox"
# "video,live,games,kinect,game,microsoft,console""
# "English"
# "native,dutch,latin,old,speakers,french,germanic,words""
# "Zach Galifianakis"
# "greek,funny,alan,movie,american,male,actors,hangover,comedy""
# "Jessica Alba"
# "dark angel,sexiest,episode,magazine,choice,nominated,award,actress""
# "Michael Jackson"
# "billy jean,grammy,artist,thriller,pop,moon walk,album,music""
# "Michael Jordan"
# "points,finals,player,career,team,chicago bulls,basketball,game,nba""
# "Vladimir Lenin"
# "workers,bolshevik,soviet,socialist,party,revolution,russian""
# "Labrador Retriever"
# "black,breeds,chocolate,kennel,yellow,breed,dog""
# "Black Death"
# "pandemic,outbreaks,bubonic,pests,population,disease,spread,europe,plague""
# "Vietnam"
# "communist,asia,chinese,hanoi,country,french,ho chi minh""
# "Entropy"
# "theory,state,statistical,energy,temperature,system,thermodynamics,heat""
# "Hentai"
# "genre,japanese,sexual,manga,erotic,anime""
# "Hydrogen"
# "energy,chemical,reaction,proton,form,compounds,water,gas""
# "World War II"
# "france,union,axis,allies,japan,forces,germany,soviet""
# "Dexter"
# "miami,hall,game,killer,murder,television,showtime""
# "Franklin D. Roosevelt"
# "polio,new deal,democratic,war,president,eleanor,fdr""
# "Fannie Mae"
# "backed,government,loan,federal,market,financial,housing,freddie mac,mortgage""
# "Peyton Manning"
# "MVP,touchdown,passes,super bowl,nfl,passing,yards,colts,season,game""
# "Tom Cruise"
# "movie,golden globe,katie holmes,film,actor,scientology""
# "Thomas Edison"
# "light,inventor,bulb,patent,electric""
# "Carbon dioxide (CO2)"
# "oxygen,doi,concentration,acid,water,gas""
# "Basketball"
# "rules,court,nba,shot,game,player,team""
# "Justin Timberlake"
# "boy band,pop,song,male,singer,NSYNC,album""
# "Chernobyl disaster"
# "core,explosion,radioactive,water,plant,steam,nuclear,power,radiation,accident,reactor""
# "Beyonce Knowles"
# "song,jay-z,awards,destiny's child,music,singer,album""
# "Pompeii"
# "town,archaeological,city,italy,roman,vesuvius,eruption,ancient""
# "Taj Mahal"
# "dome,architecture,monument,buildings,garden,india,marble,tomb""
# "Europe"
# "union,france,england,germany,russia,empire,western,roman,continent""
# "Marketing"
# "strategy,behavior,information,business,orientation,customer,consumer,firm,research,product""
# "Australia"
# "island,sydney,commonwealth,melbourne,continent,indigenous""
# "Jake Gyllenhaal"
# "film,maggie,donnie darko,male,brokeback mountain,actor""
# "Corn"
# "syrup,cob,sweet,sugar,maize,kernels""
# "Russell Wilson"
# "seattle,players,touchdowns,quarterback,rookie,seahawks,yards,season,football,nfl""
# "Microsoft"
# "products,business,gates,ibm,server,companies,software,company,windows""
# "Tiger"
# "feline,sumatran,india,species,bengal,wild,prey""
# "Jim Morrison"
# "american,musician,singer,rock,the doors""
# "Hong Kong"
# "harbour,city,government,mainland,british,region,territory,china""
# "Diabetes"
# "levels,symptoms,complications,risk,cells,disease,blood,glucose,insulin,type""
# "Butter"
# "margarine,food,fat,dairy,milk,cream,oil""
# "Eggnog"
# "drinks,brandy,cream,ingredients,food,dairy,drink,milk""
# "Bill Clinton"
# "hilary,monica lewinsky,governor,democratic,president,arkansas""
# "Denmark"
# "norway,europe,copenhagen,world,european,sweden,union,faroe,greenland,islands,danish""
# "Vegetarian"
# "rice,vegetable,foods,products,vegan,dishes,health,diet""
# "Go (game)"
# "black,chinese,rules,moves,board,players,stones""
# "Enrique Iglesias"
# "chart,music,songs,released,single,billboard,song,tour,spanish,album,latin""
# "Seven deadly sins"
# "dante,lust,latin,sloth,greed,pride,wrath,envy,gluttony""
# "Apostrophe"
# "mark,words,english,use,form,plural,names,possessive""
# "Johnny Depp"
# "roles,pirate,role,gilbert grape,actor,film,tim burton""
# "Oprah Winfrey"
# "writers,magazine,executive,women,television,american,producer,chicago,talk show""
# "Cheese"
# "protein,flavor,food,soft,fat,curd,dairy,milk""
# "Chesapeake Bay"
# "tides,potomac,susquehanna,oyster,baltimore,water,virginia,gulf,maryland,river,sea""
# "Brad Pitt"
# "actor,hollywood,male,award,role,film,angelina jolie""
# "Hyphen"
# "compound,text,dash,line,style,hyphenation,used,word,minus""
# "Tofu"
# "vegetarianism,japanese,cuisine,firm,soft,fried,protein,chinese,soy""
# "Emma Stone"
# "zombieland,movie,film,actress,spiderman,nominated,comedy,award""
# "Channing Tatum"
# "the vow,magic mike,actor,step up,male,movie""
# "Muhammad"
# "god,muslim,quran,islam,medina,mecca""
# "Ku Klux Klan"
# "organizations,groups,violence,black,civil rights,anti,southern,white,members,kkk""
# "Nuclear power"
# "fission,radioactive,accident,electricity,plants,waste,fuel,uranium,reactor,energy""
# "FIFA World Cup"
# "germany,team,international,federation,association,brazil,tournament,teams,football""
# "Anne Hathaway"
# "princess diaries,american,les miserables,academy,actress,award,film,role""
# "Dwayne Johnson"
# "hercules,triple h,wrestlemania,raw,wrestling,john cena,wwe,wwf,championship,rock""
# "Orange Is the New Black"
# "jenji,correctional,kohan,cast,season,piper,prison,television,netflix,series""
# "Taylor Swift"
# "awards,pop,songs,nashville,music,country,album""
# "Christmas"
# "tree,celebration,christian,church,religious,birth,holiday,calendar,jesus,day""
# "Human penis size"
# "circumference,inches,flaccid,men,average,erect,length""
# "HIV"
# "sexual,symptoms,cells,disease,virus,treatment,transmission,infection,risk,AIDS""
# "Kobe Bryant"
# "player,team,basketball,career,points,season,game,lakers,nba""
# "Austria"
# "europe,hungary,republic,germany,state,empire,vienna""
# "Fruit"
# "orange,apple,berries,fleshy,ovary,plant,seeds,flower""
# "Poverty"
# "health,economic,basic needs,food,welfare,living,bank,income,poor""
# "Nikola Tesla"
# "patent,westinghouse,radio,patents,motor,serbian,electrical""
# "William Shakespeare"
# "bard,sonnets,stratford,avon,henry VIII,plays""
# "Hemp"
# "sativa,plant,oil,marijuana,crop,production,cultivation,seed,fiber,paper,cannabis""
# "Friends"
# "chandler,monica,television,nbc,ross,joey,rachel,series""
# "Dog"
# "species,canis lupis,wolf,pet,wolves,domestic,breeds,human""
# "Stephen Fry"
# "actor,lgbt,twitter,series,london,english,radio,bbc""
# "Tom Hanks"
# "castaway,best,academy award,film,role,actor""
# "Adolf Hitler"
# "austrian,political,military,propoganda,dictator,nazi,war,germany""
# "Clint Eastwood"
# "actor,western,dirty harry,award,million dollar baby,best,film,director""
# "Emma Watson"
# "actress,film,brown,wallflower,perks,movie,deathly,hallows,harry potter""
# "Wiki"
# "vandalism,software,page,content,edit,users""
# "Isaac Newton"
# "theory,mechanics,force,gravity,light,cambridge,motion""
# "Disaster"
# "nuclear,hazard,vulnerability,man made,management,hazards,risk,emergency,natural""
# "Mexico"
# "city,mestizo,spain,country,spanish,indigenous,aztec""
# "Elizabeth II"
# "england,british,wales,duke,commonwealth,princess,royal,prince,queen""
# "The Lord of the Rings"
# "sauron,books,hobbit,middle earth,frodo,fantasy,tolkien""
# "One Direction"
# "x factor,single,awards,boy,charity,tour,pop,album,band""
# "Dough"
# "kneaded,pasta,leavening,cooking,baking,yeast,bread""
# "Greece"
# "century,islands,byzantine,macedonia,country,ottoman,empire,athens,greek""
# "Ship"
# "water,naval,cargo,boat,fishing,hull,vessel""
# "Cocaine"
# "crack,leaf,dopamine,use,leaves,effects,drug""
# "Islam"
# "jihad,quran,arabic,muhammad,god,muslim""
# "Hacker"
# "edit,network,black,virus,needing,unsourced,information,isbn,hacking,hat""
# "Adam Levine"
# "pop,los angeles,singers,music,rock,album,band,maroon 5""
# "Rihanna"
# "artist,singer,billboard,barbados,music,album""
# "Elvis Presley"
# "music,country,memphis,king,icon,rock n roll""
# "Bob Marley"
# "concert,rastafari,album,one love,reggae,jamaica,wailers""
# "Texas"
# "mexico,san antonio,united states,austin,largest,university,dallas,houston,state""
# "Matt Damon"
# "good will hunting,bourne series,massachusetts,award,star,actor,ben affleck""
# "Richard Nixon"
# "vice,watergate,california,scandal,president""
# "United States Constitution"
# "convention,government,law,rights,federal,supreme,congress,court,amendment""
# "Herb"
# "powder,basil,seed,plant,witchcraft,pepper,medicinal,spices,culinary""
# "Grey's Anatomy"
# "medical,abc,hospital,series,episode,doctor,drama""
# "A Christmas Carol"
# "ghost,book,tale,novels,scrooge,charles dickens""
# "Benjamin Franklin"
# "inventor,colonial,boston,founding,father,american,england,philadelphia,pennsylvania""
# "Mila Kunis"
# "black swan,performance,award,film,actress,meg""
# "Galileo Galilei"
# "sun,physics,earth,astronomer,science,italian,telescope,earth""
# "Mike Ditka"
# "nfc,cowboys,super bowl,team,players,nfl,coach,chicago,football,bears""
# "Spain"
# "madrid,peninsula,europe,mediterranean,basque,country,spanish""
# "South Park"
# "animated,series,kenny,television,chef,characters,cartman,comedy,season,show,episode""
# "World War I"
# "russia,hungary,french,austria,british,ottoman,powers,empire,battle,germany""
# "Dubai"
# "international,emirate,united arab emirates,city,emirates,uae""
# "James Franco"
# "role,man,male,california,actors,film,actor""
# "Che Guevara"
# "guerrilla,later,him,bolivian,revolutionary,revolution,castro,argentine,cuba""
# "Bob Dylan"
# "singer,rolling stone,times,folk,music,songs,album""
# "Spleen"
# "anatomy,tissue,lymphoid,organ,blood cells""
# "Ten Commandments"
# "covenant,israel,jewish,exodus,shalt,thou,god""
# "Cat"
# "animals,prey,feline,humans,species,feral,domestic""
# "Socialism"
# "labour,capitalism,production,society,state,ownership,democratic,party,economy,socialist""
# "iPhone"
# "generation,models,sim,screen,ios,apple""
# "Duck Dynasty"
# "korie,jase,kay,season,commander,family,willie,phil,robertson""
# "Avril Lavigne"
# "complicated,song,single,french,sk8ter boi,canadian,album""
# "Greenland"
# "territories,arctic,ice,inuit,expedition,island,denmark,danish""
# "Cytoplasm"
# "membrane,structures,proteins,mitochondria,nucleus,organelles,cell""
# "India"
# "asian,subcontinent,regional,empire,gdp,world,largest,population,mumbai,new delhi""
# "Gravity (film)"
# "movie,kowalski,sandra bullock,alfonso cuaron,astronaut,space""
# "The Sound of Music"
# "musical,broadway,cast,von,captain,maria von trapp""
# "Princess Diana"
# "william,marriage,family,london,lady,charles,spencer,royal""
# "Pornography"
# "actress,actor,webcam,industry,hardcore,film,sex""
# "Kenya"
# "president,british,oil,running,world,islands,east,nairobi,country,elections,africa""
# "Milk"
# "liter,bottles,calcium,cartons,cow,dairy,fat,lactose""
# "Shakira"
# "rock,music,song,spanish,colombian,latin,album""
# "Marilyn Manson"
# "actor,rock,male,metal,tour,american,band""
# "Wolverine"
# "animal,origins,avengers,logan,fictional,claw,marvel,x men""
# "Internet Movie Database"
# "websites,ratings,film,top,amazon,.com,imdb""
# "Cristiano Ronaldo"
# "uefa,season,goal,real madrid,player,portugal,league,goals""
# "Jennifer Aniston"
# "television,comedy,actress,friends,hollywood,film""
# "Wheat"
# "bread,seed,plant,wild,production,food,species,grain,crop""
# "Renaissance"
# "artists,greek,europe,century,florence,italy,art""
# "China"
# "beijing,country,population,republic,dynasty,chairman mao""
# "BMW"
# "company,motorcycles,vehicles,models,car,engine,series""
# "Cereal"
# "milk,rice,diet,food,lucky charms,captain crunch,wheat,grain""
# "Bill of Rights"
# "court,convention,congress,ratification,madison,constitution,amendment""
# "Napoleon"
# "empire,louis,waterloo,emperor,army,france,bonaparte""
# "Ukraine"
# "republic,poland,union,russia,kiev,soviet,russian""
# "Mao Zedong"
# "revolutionary,chairman,people,party,communist,revolution,china""
# "Johnny Cash"
# "tennessee,hall of fame,artists,music,songs,country,june carter""
# "Matthew Broderick"
# "musical,broadway,american,award,jewish,role,tony,actor,male""
# "The Vampire Diaries"
# "show,nina dobrev,fantasy,television,series,blood""
# "Ellie Goulding"
# "singer,music,single,album,halcyon,lights""
# "Indonesia"
# "country,asia,population,java,kalimantan,sulawesi,papua,jakarta""
# "United States"
# "country,native,gdp,income,largest,population,world,war,american,federal""
# "Polar ice cap"
# "regions,antarctica,pole,earth,nasa,mars,sea,arctic""
# "Egg"
# "fat,cholesterol,brown,hens,white,chicken,yolk""
# "The X Factor"
# "live,judge,contestants,show,auditions,simon cowell,judges""
# "Wonders of the World"
# "middle,jerusalem,pyramid,giza,natural,list,ancient,seven""
# "South Africa"
# "gauteng,black,national,republic,country,languages,cape town""
# "Jesus"
# "trinity,christianity,matthew,gospel,press,testament,god,virgin mary""
# "NASA"
# "flight,mission,shuttle,station,apollo,mars,earth,orbit,launch,program,space""
# "Seaweed"
# "red,water,brown,kelp,edible,food,algae""
# "Human"
# "people,body,genetic,between,homo sapien,species""
# "Smallpox"
# "eradication,lesions,infection,form,rash,skin,vaccine,cases,vaccination,virus,disease""
# "Brazil"
# "portugal,largest,sao paulo,country,rio de janeiro,portuguese,south america""
# "Maize"
# "food,plant,grain,ear,kernels,crop,corn""
# "Julius Caesar"
# "emperor,brutus,assassination,latin,mark antony,senate,pompey,roman""
# "Nail biting"
# "eating,habits,oral,impulse,skin,disorder,habit""
# "Martin Luther King, Jr."
# "speech,dream,assasination,movement,civil rights""
# "Buddhism"
# "practice,religion,gautama,suffering,meditation,buddha""
# "Kim Kardashian"
# "keeping,los angeles,kris humphries,reality TV,kanye west,kourtney""
# "The Great Gatsby"
# "egg,new york,buchanan,nick,novels,book,tom,daisy,novel,f scott fitzgerald""
# "Diamond"
# "cut,de beers,natural,carbon,high,color,hardness,synthetic""
# "Iran"
# "revolution,country,tehran,empire,islamic,persian""
# "Great Wall of China"
# "earth,dynasty,visible,sections,built,chinese,ming""
# "Michael Fassbender"
# "role,male,irish,supporting,nominated,film,actor,award""
# "Periodic table"
# "electrons,mendeleev,chemical,properties,group,metals,atomic,elements""
# "Belgium"
# "netherlands,waffles,german,brussels,dutch,french,belgian""
# "David Bowie"
# "ziggy stardust,artist,musician,rock,album,glam rock""
# "Keanu Reeves"
# "matrix,actor,movie,neo,male,film,canadian""
# "Kristen Bell"
# "actress,television,film,role,series,sloth,veronica mars""
# "Will Ferrell"
# "producer,comedy,awards,movie,ron burgundy,saturday night live,episode""
# "Walt Disney"
# "short,california,imagination,cartoons,animation,disneyland,mickey mouse,studio""
# "John Lennon"
# "album,england,peace,band,mccartney,beatles,yoko ono""
# "Anne Frank"
# "jewish,writers,family,german,van pels,dutch,otto,diary""
# "Snoop Dogg"
# "rapper,d-o-double g,hip hop,california,records,album,lion""
# "Kwanzaa"
# "heritage,swahili,symbols,karenga,celebrate,holiday,african""
# "Kanye West"
# "yeezy,college,chicago,artists,music,jay-z,rapper,album,hip hop""
# "Love"
# "relationship,venus,cupid,attachment,romantic,valentine""
# "Nut"
# "culinary,hazel,walnuts,pine,edible,food,seed,oil""
# "LeBron James"
# "the decision,miami heat,player,team,cleveland,points,nba,basketball""
# "Sex"
# "organisms,genetic,chromosome,reproduction,gametes,male,female""
# "Chickpea"
# "plants,flour,eaten,hummus,chana,cooked""
# "New York"
# "immigration,albany,hudson,largest,long island,city,state""
# "Adele"
# "award,music,song,singer,awards,female,artist,billboard,album""
# "Madonna"
# "songs,billboard,artist,female,vogue,pop,album,tour,music""
# "Elijah Wood"
# "frodo baggins,lord of the rings,young,film,cast,male,actor,award""
# "Theodore Roosevelt"
# "states,teddy,american,party,new york,president,taft,republican""
# "Paris Hilton"
# "heiress,role,female,hotel,american,reality,simple life,socialite""
# "Spam"
# "china,unsourced,messages,internet,mail,meat""
# "Jim Carrey"
# "mask,comedy,golden globe,male,ontario,actor,film,canadian""
# "Queen (band)"
# "john deacon,greatest,performed,brian may,roger taylor,british,album,freddie mercury,rock""
# "Philadelphia"
# "1776,freedom,delaware,pennsylvania,city""
# "Britney Spears"
# "artist,singer,madonna,justin timberlake,music,pop,album""
# "Window"
# "curtain,door,building,panes,light,heat,glass""
# "September 11"
# "terrorism,pentagon,tower,al qaeda,hijackers,flight,trade center,bin laden""
# "Vegetable"
# "green,edible,dietary,food,culinary,plant,fruit""
# "Michelangelo"
# "renaissance,lorenzo,basilica,sistine,figures,rome,works,pope,ceiling,chapel,florence""
# "Los Angeles"
# "hollywood,downtown,southern,lakers,california,city""
# "Home Alone"
# "chicago,movies,burglar,marv,family,house,harry,film,kevin McCallister,christmas""
# "Food"
# "diet,types,raw,animal,preparation,health,taste,cooking""
# "Batman"
# "gotham city,joker,comic,robin,character,bruce wayne""
# "Virginia"
# "governor,commonwealth,richmond,washington,state""
# "Christina Aguilera"
# "award,grammy,singer,song,billboard,music,album,pop""
# "Game of Thrones"
# "novels,fire,fantasy,martin,television,series,season,hbo""
# "Germany"
# "west,east,rhine,europe,empire,berlin""
# "Paul Rudd"
# "movie,television,american,anchorman,episode,jewish,male,actors""
# "Compiler"
# "machine,level,program,source,analysis,language,code""
# "Stephen Hawking"
# "medal,black hole,physics,theory,universe,genius""
# "Meat"
# "processed,production,cattle,food,beef,animal,fat,consumption,animals,cancer""
# "Linux"
# "unix,distribution,desktop,open source,free,system,operating,kernel,gnu,software""
# "Hawaii"
# "beach,honolulu,islands,state,aloha""
# "Oatmeal"
# "bran,cereals,grain,plants,soluble,whole,flour,breakfast""
# "Christmas tree"
# "holiday,spruce,pine,decorated,fir,artificial""
# "Tom Brady"
# "quarterback,record,career,yards,super bowl,game,nfl,season,patriots""
# "Wi-Fi"
# "security,radio,antenna,alliance,device,range,network,access,wireless""
# "Minecraft"
# "video,player,items,blocks,playstation,mode,games,xbox,players,game""
# "Coca-Cola"
# "advertising,soft,caffeine,drink,bottle,coke,company""
# "Meningitis"
# "antibiotics,disease,brain,meningococcal,blood,bacterial""
# "Computer virus"
# "microsoft,system,security,code,operating,programs,files,antivirus,software,windows""
# "Google"
# "internet,products,service,billion,advertising,company,search engine""
# "Arnold Schwarzenegger"
# "republican,hollywood,maria shriver,bodybuilding,governor,california,austrian""
# "Ada Lovelace"
# "women,analytical,computer,engine,babbage,byron""
# "Egypt"
# "nile,alexandria,desert,country,suez canal,arab,mummy,cairo,pyramid""
# "Jimi Hendrix"
# "musician,playing,electric,rock,band,experience,guitar""
# "George VI"
# "elizabeth,queen,princess,grand,albert,duke,edward,prince,king,royal""
# "Antarctica"
# "ozone,polar,sheet,pole,land,sea,continent,ice""
# "BDSM"
# "partner,submission,dominance,consent,leather,bondage,play,sex,sexual""
# "Korean War"
# "soldiers,38th parallel,china,south,soviet,army,forces,north""
# "Earth"
# "life,land,plate,water,solar,atmosphere,planet,sun,moon,surface""
# "Copenhagen"
# "frederiksberg,europe,museum,church,denmark,city,danish""
# "Dementia"
# "syndrome,age,symptoms,mental,brain,pain,disorder,alzheimer,cognitive,disease""
# "Cloud"
# "cirrus,precipitation,high,low,air,weather,cumulus""
# "French Revolution"
# "constitution,liberty,louis,republic,king,france,assembly""
# "Nicki Minaj"
# "rapper,billboard,album,female,pink,super bass""
# "Kelly Clarkson"
# "grammy,tour,pop,billboard,album,american idol""
# "Religion"
# "mosque,church,temple,catholicism,god,spirituality,islam,mythology,belief,christianity""
# "Twilight (series)"
# "jacob,forks,dawn,novel,vampire,meyer,books,edward,bella""
# "Down syndrome"
# "hearing,screening,trisomy,age,diagnosis,children""
# "Mad Men"
# "weiner bros,show,television,sterling cooper,series,episode,amc,don draper,advertising""
# "Agnosticism"
# "belief,christian,religious,atheism,existence,religion,god""
# "Thomas Jefferson"
# "slaves,congress,united states,president,virginia""
# "Bradley Cooper"
# "film,movie,hangover,male,actor,award""
# "Spice"
# "dried,ginger,seed,powder,trade,oil,food,herbs,pepper""
# "Netherlands"
# "europe,north,islands,amsterdam,republic,country,holland,kingdom,dutch""
# "Tuberculosis"
# "test,hiv,health,risk,treatment,infection,disease""
# "Apartheid"
# "anc,homelands,racial,coloured,white,government,black,south africa""
# "Apple Inc."
# "products,macintosh,ipod,store,ipad,mac,company,steve jobs,iphone""
# "Julie Andrews"
# "english,golden globe,actress,musical,sound of music""
# "Karl Marx"
# "frederick,class,socialism,manifesto,communist,philosophy,german""
# "Robert Downey, Jr."
# "movie,male,role,actor,film,iron man""
# "Photosynthesis"
# "plant,cycle,energy,oxygen,water,electron,reactions,plants,carbon dioxide,light""
# "Instagram"
# "facebook,services,filters,phone,sharing,kevin systrom,terms,photos,app,users""
# "Winter solstice"
# "midwinter,astronomical,festivals,day,hemisphere,sun,observances,holidays""
# "Metallica"
# "kirk hammett,cliff burton,death magnetic,studio,guitar,rock,james hetfield,lars ulrich,album,band""
# "Jupiter"
# "red,hydrogen,spot,mass,orbit,earth,sun,solar,atmosphere,moons,planet""
# "Sigmund Freud"
# "psychology,ego,id,press,unconscious,theory,psychoanalysis""
# "Charles Dickens"
# "great expectations,author,english,characters,novels""
# "iPad"
# "ios,model,cellular,screen,mini,generation,apple""
# "Will Smith"
# "gettin' jiggy,fresh prince,jada,american,star,film,actors,male,philadelphia""
# "Katy Perry"
# "teenage dream,music,kissed a girl,california girls,album""
# "Spider-Man"
# "comic,stan lee,gwen stacy,mary jane,peter parker,marvel,character,amazing,comics""
# "Glee"
# "fox,musical,comedy,television,cast,episode,rachel berry,show,season""
# "Wikipedia"
# "project,encyclopedia,foundation,editions,wales,article,content,editors""
# "France"
# "louis,bonjour,country,republic,europe,paris,french""
# "Sydney"
# "street,bureau,park,theatre,harbour,wales,city,australia""
# "Android"
# "code,kernel,source,hardware,applications,linux,software,google,device""
# "Pi"
# "irrational,series,number,mathematics,infinite,circle,digits""
# "Pea"
# "vegetable,food,fresh,split,eaten,green,plants""
# "Meme"
# "reddit,funny,troll,ideas,internet,cultural,evolution""
# "Godzilla"
# "appearance,portrayed,king,film,nuclear,japanese,toho,gojira,fictional,monster,character""
# "New York City"
# "wall street,metropolitan,population,brooklyn,cities,borough,long island,manhattan""
# "Water"
# "food,chemical,oxygen,liquid,surface,temperature,drinking,ice,heat,hydrogen,earth""
# "Pope Francis"
# "cardinal,vatican,argentina,catholic,buenos aires,church,bergoglio""
# "Amazon.com"
# "service,business,products,jeff bezos,company,prime,books,sales,online,companies""
# "Fibonacci number"
# "golden,prime,mathematics,ratio,sum,sequence""
# "Vietnam War"
# "troops,south,viet cong,forces,ho chi minh,communist,military,north""
# "Mike Tyson"
# "ring,sports,round,holyfield,win,heavyweight,fight,boxing""
# "Abraham Lincoln"
# "confederate,party,war,ulysses s. grant,president,republican,union,illinois,slavery""
# "Kurt Cobain"
# "star,teen spirit,rock,band,courtney love,nirvana""
# "NCIS (TV series)"
# "drama,seasons,police,television,episode,investigation,agent gibbs,cbs""
# "Standard deviation"
# "average,data,random,values,distribution,variance,population,sample,mean""
# "Hospitality"
# "southern,needing,industry,host,lacking,guest""
# "Winston Churchill"
# "england,leader,british,World War 2,prime minister,war""
# "Mark Zuckerberg"
# "CEO,company,college,internet,social network,harvard,facebook""
# "R. Kelly"
# "music,male,song,closet,ignition,album""
# "Freddie Mercury"
# "gay,solo,aids,album,band,greatest,rock,queen""
# "Computer"
# "modern,languages,stored,architecture,instructions,memory,program,machine""
# "Sherlock"
# "doyle,mark,watson,doctor,television,episode,gatiss,moffat,bbc,holmes""
# "Ivy League"
# "sports,columbia,cornell,brown,college,penn,schools,harvard,university,yale,princeton""
# "Jason Statham"
# "british,fast and furious,crank,english,film,transporter,expendables""
# "Warren Buffett"
# "rich,investment,omaha,company,business,billion,stock,hathaway,berkshire""
# "Autism"
# "behavior,syndrome,diagnosis,brain,social,individuals,disorders,symptoms,children""
# "Superman"
# "lex luther,smallville,lois lane,characters,clark kent,character,dc comics""
# "Adriana Lima"
# "alessandra,brazilian,fashion,model,victoria's secret""
# "Ben Affleck"
# "male,matt damon,movie,american,award,film,actor""
# "The Big Bang Theory"
# "howard,episode,amy,series,penny,comedy,leonard,sheldon,season""
# "Garth Brooks"
# "songwriter,singer,oklahoma,album,music,country""
# "Bipolar disorder"
# "diagnosis,symptoms,mood,depression,manic,episodes""
# "Twerking"
# "booty,afro,rapper,culture,hip hop,song,dance""
# "Ireland"
# "europe,britain,dublin,beer,republic,island,northern,irish""
# "Drake (rapper)"
# "toronto,take care,billboard,money,album,single,song,canadian""
# "Kendrick Lamar"
# "california,hip hop,rapper,song,duckworth,album""
# "USB"
# "micro,bus,cable,plug,bandwidth,connectors,data,power,host,device""
# "Chicago"
# "lake shore,united center,university,north side,millenium park,illinois,city""
# "Greenhouse gas"
# "climate,methane,change,energy,atmosphere,carbon dioxide,emissions""
# "California"
# "west,water,coast,los angeles,largest,valley,san francisco,state""
# "Watt"
# "kilo,mega,energy,units,power""
# "Thailand"
# "royal,economy,kingdom,country,southeast,asia,bangkok""
# "Berlin Wall"
# "western,fall,eastern,allied,soviet,border,germany""
# "George Clooney"
# "oceans eleven,golden globe,film,academy,award,actor""
# "Osama bin Laden"
# "sudan,united states,attacks,pakistan,afghanistan,saudi,al qaeda""
# "Macaulay Culkin"
# "american,michael jackson,movie,home alone,amp,actor,male""
# "Poland"
# "soviet,slavic,country,war,europe,warsaw""
# "Andy Warhol"
# "artist,paintings,pop,new york,factory,art""
# "The Nutcracker"
# "russian,orchestra,sugar plum fairy,music,dance,tchaikovsky,ballet""
# "Mariah Carey"
# "career,pop,artist,billboard,song,music,album""
# "Washington, D.C."
# "capital,states,federal,congress,columbia,national,city,district""
# "Snapchat"
# "disappear,images,sent,photos,company,users,app,android""
# "SpongeBob SquarePants"
# "animation,show,sea,animated,patrick,pineapple,television,series,nickelodeon""
# "Leonardo da Vinci"
# "inventor,drawings,paintings,milan,verrocchio,renaissance,florence,painting""
# "Schizophrenia"
# "psychosis,treatment,diagnosis,medication,psychotic,risk,disorder,symptoms""
# "Futurama"
# "animated,philip fry,show,bender,comedy central,series,television,fox""
# "Bill Gates"
# "software,CEO,ibm,melinda,computer,microsoft""
# "Taiwan"
# "president,political,government,mainland,island,taipei,prc,republic,china""
# "Al Capone"
# "torrio,brooklyn,massacre,alcatraz,prohibition,gang,chicago""
# "Fifty Shades of Grey"
# "series,novels,bdsm,fan,trilogy,fiction,book,christian,ana""
# "Sandra Bullock"
# "box office,film,blind side,gravity,award,actress""
# "Italy"
# "empire,gdp,roman,europe,rome,country,pasta""
# "Frank Sinatra"
# "album,nancy,legend,career,actor,singer,award""
# "Modern Family"
# "ratings,comedy,abc,television,show,series,season""
# "Charles Darwin"
# "finch,society,man,ideas,evolution,theory,natural selection,species""
# "Hinduism"
# "india,dharma,yoga,karma,god,vedic,religion""
# "Julia Roberts"
# "movie,golden globe,american,film,pretty woman,actress""
# "Narcissism"
# "social,psychology,disorder,personality,self,love""
# "Israel"
# "relations,tel aviv,gaza,hebrew,palestine,arab,jerusalem,jewish""
# "Dr. Dre"
# "artists,produced,mentor,records,snoop dogg,eminem,aftermath,album,rap""
# "Jackie Chan"
# "actor,action,martial arts,nominated,chinese,film,hong kong""
# "Ashton Kutcher"
# "actor,american,male,punkd,that 70s show,iowa,executive,producer""
# "Bean"
# "seeds,dry,plants,corn,food,lima,broad""
# "Nineteen Eighty-Four"
# "oceania,dystopia,war,ministry,big brother,novels,george orwell,winston smith,party""
# "Miley Cyrus"
# "MTV VMAs,pop,billboard,song,single,album,hannah montana""
# "Pasta"
# "egg,ingredients,italy,sauce,dough,wheat,fresh,flour,macaroni,dried""
# "Ryan Gosling"
# "the notebook,man,actor,micky mouse club,film,canadian,january""
# "Operating system"
# "linux,file,hardware,unix,program,memory,windows,computer,kernel""
# "Jakarta"
# "port,dutch,international,asia,museum,capital,area,city,indonesia""
# "John F. Kennedy"
# "brother,administration,nuclear,assasination,civil rights,vietnam,president""
# "Christian Bale"
# "english,male,role,film,actor,batman""
# "Jennifer Lopez"
# "bronx,j lo,american,latina,music,album,dance,film""
# "Linkin Park"
# "meteora,a thousand suns,musical,hybrid theory,shinoda,rock,album,band""
# "Dinosaur"
# "bone,modern,species,fossil,cretaceous,evidence,jurassic,birds""
# "American Revolutionary War"
# "patriot,freedom,independence,washington,battle,french,army,british""
# "Capitalism"
# "value,social,state,political,labor,production,economics,economy,market,economic""
# "Soviet Union"
# "communist,war,russia,party,stalin,ussr""
# "Houston"
# "astros,airport,rockets,NASA,south,city,texas""
# "Blogger"
# "post,buzz,mobile,users,blogspot,online,internet,write""
# "Christopher Columbus"
# "1492,america,india,island,governor,spanish,voyage""
# "United Kingdom"
# "welsh,britain,northern,england,wales,scotland,ireland""
# "Iceland"
# "expedition,island,countries,norse,country,world,reykjavik""
# "Henry VIII"
# "mary,france,ireland,marriage,cromwell,anne boleyn,king,catherine,england""
# "Edgar Allan Poe"
# "boston,poems,works,raven,literary,death,baltimore,writers,virginia""
# "Mistletoe"
# "seeds,branch,kiss,berries,christmas,plant,species,plants""
# "Ramesses II"
# "tomb,king,temple,battle,pharaoh,dynasty,egypt""
# "Bitcoin"
# "payment,virtual,financial,transactions,money,currency""
# "Crime"
# "statements,state,justice,against,legal,theory,offence,law""
# "Mahatma Gandhi"
# "movement,hindu,independence,british,nonviolence,congress,india,peace""
# "Coen brothers"
# "won,academy,producers,award,film,ethan,sibling,directors,joel""
# "Vladimir Putin"
# "medvedev,moscow,soviet,prime minister,president,relations,russia""
# "Internet"
# "software,computer,users,protocol,world wide web,services,network""
# "San Francisco"
# "market,mission,north,golden gate,california,bay,city""
# "American Civil War"
# "virginia,secession,emancipation,states,battle,southern,confederacy,lincoln,slavery,union""
# "Paul McCartney"
# "john lennon,england,ringo starr,band,george harrison,beatles""
# "Raven"
# "magpie,bird,food,species,crow,jay,birds""
# "Angelina Jolie"
# "role,movie,golden globe,film,actress,award,brad pitt""
# "Flour"
# "rye,grain,protein,gluten,bread,wheat""
# "Football"
# "quarterback,play,league,field,line,team,players,nfl,game,rules""
# "YouTube"
# "internet,users,google,site,content,video""
# "Prohibition"
# "liquor,consumption,temperance,act,dry,law,enforcement,amendment,alcohol""
# "Quinoa"
# "agriculture,value,wild,species,plant,andes,food,seeds,crop,chenopodium""
# "Heroin"
# "addicts,injection,users,overdose,opium,use,drug,morphine""
# "Berkeley"
# "hall,universities,students,school,college,student,campus,california""
# "Inception"
# "thief,box office,dom cobb,film,dream,christopher nolan""
# "World Wide Web"
# "information,hypertext,browser,http,server,www,internet""
# "David Beckham"
# "real madrid,manchester,team,player,club,galaxy,cup,match,league,england""
# "Jamaica"
# "independence,west,bay,kingston,british,national,caribbean,spanish,island""
# "Barack Obama"
# "joe biden,hilary clinton,illinois,president,senate,chicago""
# "Vin Diesel"
# "award,producer,film,actors,furious,male,fast,riddick""
# "England"
# "royal,wales,britain,london,united kingdom,english""
# "New Zealand"
# "february,culture,islands,ministry,island,wildlife""
# "Jimmy Carter"
# "bush,election,governor,democratic,peace,president,georgia""
# "Pakistan"
# "military,region,power,muslim,country,nuclear,kashmir,islamic,punjab""
# "Kim Jong-un"
# "workers,dictator,Kim Jong-il,Kim Il-sung,supreme,north korea""
# "Amino acid"
# "synthesis,chain,cell,biology,protein""
# "Bait"
# "small,rig,fly,shark,rod,predators,forage,net,fishing""
# "The Rolling Stones"
# "blues,rock,bill wyman,london,album,tour,keith richards,band,mick jagger""
# "The Hunger Games"
# "author,tributes,peeta,capitol,book,suzanne collins,novel,katniss""
# "Fidel Castro"
# "communist,batista,revolution,socialist,president,havana,government,cuba""
# "John Cena"
# "feud,defeated,wrestling,raw,championship,wwe,match""
# "Kenan Thompson"
# "guest,saturday night live,episodes,kel,atlanta,episode,cast,actors,male""
# "Honey"
# "beekeeping,glucose,sugar,sticky,food,water,bee""
# "Victoria's Secret"
# "show,catalog,brands,store,company,fashion,lingerie""
# "London"
# "westminster,thames,royal,city,england""
# "Lorde"
# "singer,music,top,song,pure heroine,pop,royals,new zealand""
# "Selfie"
# "photo,art,mirror,portraits,color,photography,camera""
# "Lil Wayne"
# "musician,rapper,cash,single,young,money,album,tha carter""
# "Vincent van Gogh"
# "gauguin,paris,dutch,museum,art,france,ear,painting""
# "Java"
# "colonial,islamic,jakarta,rice,island,indonesia,javanese,programming,coffee""
# "Bangladesh"
# "asia,government,country,pakistan,region,dhaka,bengal""
# "Democracy"
# "elections,university,government,rule,citizens,representative,direct,press,political""
# "Entertainment"
# "music,performance,press,games,theatre,dance,audience""
# "Peanut"
# "nut,allergy,roasted,butter,oil""
# "Ugg boots"
# "brand,new zealand,fashion,footwear,shoes,sheepskin,australia""
# "Mars"
# "atmosphere,rover,water,martian,surface,earth,planet""
# "How I Met Your Mother"
# "robin,episode,bays,barney,final,ted""
# "Methamphetamine"
# "psychosis,acid,withdrawal,effects,drug,dopamine""
# "Macklemore"
# "rapper,song,thrift shop,heist,hip hop,music,ryan lewis""
# "Singapore"
# "government,language,economy,world,english,country,independence,malaysia,malay,chinese""
# "Global warming"
# "increased,mean,changes,temperatures,effects,surface,change,models,greenhouse,emissions,climate,temperature""
# "Scarlett Johansson"
# "movie,reviews,critics,role,actress,film""
# "Gelatin"
# "food,material,products,animal,fat,water,collagen""
# "Facebook"
# "million,like,profile,website,privacy,social network,friends,zuckerberg,user""
# "Alexander the Great"
# "macedonian,death,king,empire,persian,greek,philip""
# "Teenage Mutant Ninja Turtles"
# "raphael,action,michelangelo,episodes,comic,leonardo,donatello,series,tmnt""
# "Pablo Picasso"
# "cubism,artists,painting,paris,museum,spanish,art""
# "Led Zeppelin"
# "robert plant,jimmy page,music,bonham,album,rock,band""
# "Tupac Shakur"
# "rap,west coast,notorious big,hip hop,death,album""
# "Genghis Khan"
# "china,father,dynasty,mongolia,temujin,empire,mongol""
# "Scientology"
# "spiritual,organization,auditing,dianetics,religion,hubbard,church""
# "Sweden"
# "denmark,scandinavia,king,europe,country,stockholm""
# "Family Guy"
# "characters,griffin,animated,season,television,episode,series,fox,show,seth macfarlane""
# "Anime"
# "characters,style,genres,art,manga,works,japanese,animation""
# "Russia"
# "europe,asia,putin,world,country,moscow,soviet union""
# "Santa Claus"
# "tradition,presents,dutch,father,gifts,saint,postal,letters,christmas,nicholas,children""
# "Pollution"
# "human,control,contamination,chemical,environment,health,soil,industrial,water,waste,air""
# "Vegetable oil"
# "fat,extraction,food,acid,hydrogenated,trans,cooking""
# "Greek alphabet"
# "symbol,unicode,sound,latin,vowel,ancient,modern,letter""
# "Mona Lisa"
# "museum,portrait,art,woman,louvre,leonardo da vinci,painting""
# "Pink Floyd"
# "the wall,richard wright,nick mason,syd barrett,album,band,david gilmour,roger waters""
# "Lion"
# "africa,lioness,male,species,cubs,pride""
# "Breaking Bad"
# "hank,meth,gus,walt,television,series,jesse,season,walter""
# "Japan"
# "china,military,okinawa,nippon,islands,tokyo,emperor,konichiwa,samurai""
# "Lentil"
# "rice,starch,protein,food,nutritional,red,green""
# "Sriracha sauce"
# "foods,sauce,cuisine,curry,asian,pepper,hot,thai""
# "Leonardo DiCaprio"
# "gilbert grape,titanic,inception,los angeles,golden globe,actor,film""
# "Lobotomy"
# "medical,lobes,psychosurgery,procedure,mental,patients,brain,frontal""
# "Daft Punk"
# "grammy,electronic,awards,bangalter,album,music,duo""
# "Psychology"
# "social,clinical,mental,methods,human,behavior,study,cognitive,research""
# "Asperger syndrome"
# "behavior,symptoms,spectrum,social,children,diagnosis,disorder,autism""
# "Solar System"
# "mars,saturn,neptune,orbit,jupiter,planet,earth,planets,sun""
# "Scotland"
# "north,edinburgh,glasgow,england,parliament,united kingdom,scottish""
# "Dairy"
# "food,yogurt,butter,cheese,whey,fermented,cream,milk""
# "Barley"
# "wheat,plant,grain,malting,straw""
# "Friday the 13th"
# "cycle,months,superstitions,unlucky,superstition,month""
# "Harry Potter"
# "ron weasley,hermoine,dumbledore,hogwarts,voldemort,series,JK rowling,book""
# "George Washington"
# "slaves,president,congress,french,british,continental,vernon,mount,army,revolutionary""
# "Gross domestic product"
# "country,national,goods,production,economic,accounts,value,capita,income,gdp""
# "Finance"
# "behavioral,planning,economics,corporate,market,investment,management,risk,capital,cash""
# "Bali"
# "population,road,foreign,hindu,isbn,dutch,tourist,tourists,jakarta,tourism,indonesia,island,balinese""
# "Pickling"
# "preservation,cucumbers,vinegar,cabbage,peppers,salt,carrots,food,vegetables""
# "Assassin's Creed"
# "memories,games,brotherhood,animus,player,altair,game,desmond,ezio""
# "Joseph Gordon-Levitt"
# "summer,inception,jewish,american,film,actors,male""
# "Lindsay Lohan"
# "mean girl,actress,nominated,movie,teen,film,award,parent trap""
# "Puerto Rico"
# "united states,caribbean,commonwealth,san juan,island,spanish""
# "Morgan Freeman"
# "american,film,tennessee,directors,award,actor,mississippi""
# "NBA"
# "championship,season,lakers,finals,player,games,team,league,national""
# "Pearl Harbor"
# "navy,fleet,damaged,war,wave,pacific,uss,japan,aircraft""
# "Bread"
# "crust,water,sourdough,bake,made,leavening,wheat,yeast,dough,flour""
# "DNA"
# "these,structure,called,bases,genetic,helix,proteins,rna,strand,strands,double,sequence,base""
# "Columbine"
# "cafeteria,shooting,library,students,school""
# "Chinese New Year"
# "spring,traditional,china,firecrackers,february,red,festival,holidays,day""
# "Pneumonia"
# "streptococcus,influenza,respiratory,viral,symptoms,chest,bacteria,disease,lung""
# "Switzerland"
# "europe,council,geneva,french,german,swiss""
# "Joseph Stalin"
# "eastern,central,order,lenin,party,war,,russian,soviet union""
# "Wolfgang Amadeus Mozart"
# "father,composer,opera,works,composers,salzburg,vienna,solomon""
# "Star Wars"
# "clone,darth vader,empire,luke skywalker,films,trilogy,series,jedi,george lucas""
# "Malcolm X"
# "shabazz,civil rights,african,black panthers,muhammad,nation,islam""
# "Gold"
# "coin,silver,alloys,mercury,metal,golden""
# "Uruguay"
# "brazil,country,spanish,south america,argentina""
# "Twitter"
# "social,messages,jack dorsey,internet,service,user,tweet""
# "Africa"
# "central,southern,egypt,continent,north,saharan""
# "Roman numerals"
# "symbols,arabic,latin,numbers,clock,iiii""
# "Paul Walker"
# "american,conner,brian,episode,california,film,actor,male,fast,furious""
# "George W. Bush"
# "republican,approval,september 11,iraq,texas,president""
# "Kim Jong-il"
# "foreign,pyongyang,leader,korean,north korea""
# "Cold War"
# "revolution,berlin,nuclear,europe,stalin,military,communist,soviet union""
# "Boxing Day"
# "retailers,canada,sales,december,christmas,holiday""
# "Industrial Revolution"
# "conditions,power,water,production,engine,cotton,machine,coal,britain,iron,steam""
# "Steve Jobs"
# "california,disney,pixar,ceo,steve wozniak,company,computer,apple""
# "Blog"
# "links,journalism,news,political,personal,popularity,online,comments,media""
# "Doctor Who"
# "show,time travel,telephone booth,daleks,broadcast,episode,television,bbc,series""
# "Jennifer Lawrence"
# "katniss,performance,academy award,best actress,hunger games,role,film""
# "Audrey Hepburn"
# "role,film,academy,unicef,award,actress,british""
# "Kesha"
# "jack daniels,song,singer,rock,animal,pop,album,party""
# "Ronald Reagan"
# "campaign,nancy,tax,actor,cold war,republican,california,president""
# "United Nations"
# "organization,secretary,member,peacekeeping,security,international,assembly,general,council""
# "Marilyn Monroe"
# "los angeles,president,norma jeane,film,blonde,kennedy""
# "Mount Everest"
# "himalayas,expedition,nepal,base,mountain,camp,oxygen,climbers,summit""
# "RMS Titanic"
# "sinking,star,aboard,lifeboats,crew,deck,passengers,class,ship""
# "Bruno Mars"
# "singer,artist,music,song,album,pop,songs,grenade""
# "Justin Bieber"
# "song,never say never,believe,belieber,album,twitter,canadian""
# "Zooey Deschanel"
# "award,film,american,comedy,summer,actress""
# "Philippines"
# "asia,filipino,islands,country,manila,spanish""
# "Parks and Recreation"
# "nbc,series,show,leslie knope,comedy,amy poehler,season""
# "Rebecca Black"
# "single,youtube,factory,katy perry,pop,song,video,music,friday""
# "Baking"
# "hot,pastry,frying,goods,food,cooking,heat,oven,bread""
# "Netflix"
# "subscribers,company,video,rental,dvd,movies,service,streaming""
# "Quentin Tarantino"
# "django unchained,pulp fiction,nominated,award,kill bill,director,film""
# "North Korea"
# "japanese,country,china,nuclear,peninsula,south,pyongyang,kim""
# "Lady Gaga"
# "tour,monster,lgbt,fashion,pop,born that way,fame,music""
# "Bob Barker"
# "daytime,host,price is right,show,game""
# "Demi Moore"
# "bruce willis,movie,film,ashton kutcher,actress,award""
# "Robert De Niro"
# "academy,martin scorsese,film,award,actor""
# "Adam Sandler"
# "american,jewish,film,actors,male,happy gilmore,billy madison,comedian""
# "Carrie Underwood"
# "music,top,album,awards,artist,billboard,female,country""
# "Great Depression"
# "money,bank,prices,recession,recovery,unemployment,federal reserve,new deal,economy""
# "Climate change"
# "science,sea,global,ocean,temperature,variations,solar,earth,ice""
# "Illuminati"
# "organizations,theory,order,secret,conspiracy,bavarian""
# "American Horror Story"
# "retrieved,ryan,october,lange,television,asylum,series,murphy,season""
# "Cuba"
# "press,states,havana,latin,caribbean,castro,spanish""
# "Jay-Z"
# "brooklyn,american,record,shawn carter,roc-a-fella,artist,mogul,blueprint,album""
# "fawn"
# "brown,Bambi,doe,young,deer""
# "skis"
# "crosscountry,snowboard,snow,snowplow,mountain""
# "allergy"
# "cats,watery eyes,pollen,cough,sneeze""
# "month"
# "day,calendar,bills,period,time""
# "alien"
# "foreign,species,human,world,outer space,country""
# "straws"
# "suction,hay,drink,sucking,tube""
# "Olympics"
# "medals,games,host,flames,athlete,sports""
# "skin"
# "epidermis,tan,flesh,color,body""
# "moon"
# "NASA,star,orbit,tide,Earth""
# "milk"
# "lactose,dairy,cow,cream,white""
# "apartment"
# "rent,live,room,building,home""
# "lyrics"
# "music,lookup,words,song,poetry""
# "electricity"
# "electrons,charge,lightning,outlet,conducts""
# "father"
# "mother,dad,papa,male,parent""
# "Evil"
# "hell,devil,exorcised,good,witches""
# "tail"
# "bone,balance,limb,cat,dog""
# "abode"
# "home,house,nomadic,residence,kingdom,humble""
# "fax"
# "phone,send,document,email,machine""
# "smartphone"
# "blackberry,android,computer,iPhone,phone""
# "garden"
# "trees,flowers,house,yard,plants""
# "dessert"
# "sweet,dinner,after,cookies,cake""
# "oceans"
# "Pacific,Atlantic,continent,water,sea""
# "rhyme"
# "lines,poems,correspondence,sound,endings,words""
# "eyelashes"
# "false,bat,eyes,hairs,lash""
# "fat"
# "fries,unhealthy,food,saturated,trans""
# "spoon"
# "liquid,utencil,spork,knife,fork""
# "diary"
# "private,day,record,write,notebook""
# "jack"
# "points,man,divided,raise,key,honor""
# "masturbate"
# "porn,sex,finger,jerk,stimulate""
# "cook"
# "baker,profession,heat,food,chef""
# "fur"
# "dogs,animals,skin,coat,hair""
# "Mesopotamia"
# "ferticle crescent,tigris,iraq,babylonia,civilization""
# "matrices"
# "brackets,numbers,multiplication,addition,linear algebra""
# "school"
# "student,education,universty,graduate,college""
# "parrot"
# "tropics,speek,colors,echo,bird,cage""
# "tricycle"
# "three,wheel,bicycle,cycle,unicycle""
# "knight"
# "chivalry,warrior,medieval,suit,armor""
# "gum"
# "spearmint,pack,mint,swallow,resin,chew""
# "dinosaur"
# "extinct,T-Rex,enormous,animal,comet""
# "sand"
# "desert,dunes,glass,grain,beach""
# "saxophone"
# "woodwind,keys,jazz,reed,instrument""
# "math"
# "equations,numbers,science,subject,school""
# "sidewalk"
# "shoulder,crosswalk,pedestrians,road,walking""
# "sewage"
# "sanitation,waste,underground,toilet,sewer""
# "NPR"
# "listen,Ira Glass,radio,national,public""
# "Mecca"
# "pilgrimage,pray,Hijra,mosque,Muhammad""
# "doorbell"
# "sound,bell,arrival,building,house""
# "attic"
# "space,storage,room,building,top""
# "tea"
# "leaves,green,calm,cup,brewing""
# "bacon"
# "eggs,cured,pork,fat,pig""
# "sabbath"
# "religous,worship,sunday,saturday,evening""
# "nail"
# "stud,finger,haystack,wall,hammer""
# "invention"
# "scientific,original,process,concept,patent""
# "video"
# "camera,image,screen,stream,audio""
# "hummingbird"
# "flowers,fast,small,wings,bird""
# "download"
# "music,movie,data,copy,disk,upload,computer""
# "acid"
# "burn,chemistry,pH,base,trip""
# "pajamas"
# "comfy,wear,sleep,pants,bed""
# "port"
# "coast,cargo,harbor,docks,ships""
# "chalk"
# "crayon,drawing,writing,blackboard,board""
# "LSD"
# "flashbacks,acid,hallucinogens,drop,trip""
# "checkers"
# "game,kings,black,white,Chess""
# "clock"
# "hours,second,minutes,time,ticks""
# "sun"
# "heat,light,orbit,tanning,star""
# "orchestra"
# "conductor,string,symphony,music,instrument""
# "caffeine"
# "four loko,tea,chemcial,stimulant,soda,coffee""
# ...
# "Afghanistan"
# "country,taliban,Desert Storm,forces,war,Persian""
# "picnic"
# "food,blanket,basket,lunch,park""
# "vine"
# "stem,climbing,plant,ivy,grape""
# "Christianity"
# "missionary,son,religion,cross,God,Jesus""
# "nun"
# "celibacy,religion,veil,costumes,priest""
# "computer"
# "mouse,keyboard,monitor,PC,MacBook,program""
# "college"
# "learn,study,education,university,school""
# "violet"
# "red,flower,blue,purple,lilac""
# "portrait"
# "art,picture,oils,photo,landscape""
# "surgery"
# "scapel,doctor,hospital,operation,cut""
# "senator"
# "legislature,government,Congress,politician,congressman""
# "hammer"
# "screwdriver,drill,tool,metal,nail""
# "diver"
# "jump,water,sport,swim,olympic""
# "gladiator"
# "death,ancient,arena,The Coluseum,fight,Roman""
# "barn"
# "cows,hay,owl,farm,building""
# "shower"
# "bathroom,bathe,clean,water,bath""
# "vitamins"
# "dose,daily,deficiency,fortified,protection""
# "closet"
# "private,skeleton,bedroom,hang,storage,clothes""
# "movie"
# "silver screen,actors/actresses,film,watch,theater""
# "nightmare"
# "sweat,scary,night,sleep,dream""
# "sail"
# "cruises,sea,boat,wind,ship""
# "freshmen"
# "sophomores,college,young,year,first""
# "Oregon"
# "west,Pacific,Washington,state,trail""
# "grandmother"
# "son,family,parent,father,mother""
# "genius"
# "Apple,intelligent,prodigy,creative,smart""
# "unions"
# "labor,strikes,political,organized,association""
# "ink"
# "lead,pencil,pen,quill,write""
# "skyscraper"
# "New York,skyline,building,tall,construction""
# "yogurt"
# "milk,fermented,sweetened,snack,flavors""
# "torpedo"
# "vanes,ship,explode,submarine,missle""
# "funeral"
# "dead,body,procession,graveyard,burial""
# "monarchy"
# "dictator,democracy,queen,king,crown""
# "supermarket"
# "store,produce,food,shop,groceries""
# "lotion"
# "soft,dry,sunblock,moisturizer,skin""
# "guitar"
# "music,strumming,banjo,string,instrument""
# "seafood"
# "shellfish,cuisine,fish,lobster,food""
# "jog"
# "walk,light,exercise,gentle,run""
# "cousin"
# "parent,child,second,removed,first""
# "mailbox"
# "post office,mail,drop,seal,box""
# "shoe"
# "barefoot,feet,boots,heels,lace""
# "FBI"
# "federal,agent,government agency,law enforcement,CIA""
# "kitchen"
# "stove,pantry,fridge,cook,food""
# "toothbrush"
# "clean,brush,toothpaste,teeth,bristles""
# "accident"
# "surviving,car,chance,happened,witness""
# "rugby"
# "goal,kick,tackle,football,England""
# "NATO"
# "atlantic,European,countries,UN,north""
# "joke"
# "knock-knock,comedian,say,humor,funny""
# "iPod"
# "Apple,touch,video,mp3,music,shuffle""
# "pulp"
# "pines,orange,fiction,mill,paper""
# "plankton"
# "shark,whale,sea,animals,ocean""
# "witch"
# "spells,girl,woman,magic,broomstick""
# "cemetery"
# "ground,tombstone,graveyard,bury,dead""
# "wheelbarrow"
# "wheel,gardening,loads,carrying,barrows""
# "quadrilateral"
# "geometry,kite,rectangle,four,sided""
# "homosexuality"
# "closet,gender,same,attracted,sex""
# "badminton"
# "racket,shuttlecock,net,double,singles""
# "harpoon"
# "sea,fishing,spear,fired,shaft""
# "church"
# "Christian,pew,cross,altar,worship""
# "mafia"
# "godfather,mob,crime,organized,family""
# "Disney"
# "animation,Mickey Mouse,cartoon,movie,Walt""
# "headlights"
# "drive,car,deer,lights,bright""
# "poem"
# "recital,poetry,epic,song,rhyming""
# "lighthouse"
# "sea,ships,light,Alexandria,lanterns""
# "inhale"
# "weed,vapors,breathing,gasping,fumes""
# "beef"
# "roasted,flesh,cows,sausage,steaks,cut""
# "instrument"
# "reed,string,blowing,music,play""
# "vacation"
# "holiday,break,work,travel,cruises""
# "submarine"
# "ocean,underwater,patrol,torpedo,sea""
# "beer"
# "alcohol,craft,barrel,brewing,draft""
# "acre"
# "yards,square,parcel,feet,land,measurement""
# "peppers"
# "cayenne,spice,green,red,food,hot""
# "helicopter"
# "Marine One,rotors,fan,float,plane""
# "trinity"
# "holy spirit,father,son,three,god""
# "imam"
# "Muhammad,religion,prayer,Islam,leader""
# "life"
# "blood,grave,age,birth,death""
# "Poseidon"
# "Greek,god,sea,son,Neptune,trident""
# "nickel"
# "penny,cent,coin,five,iron""
# "squirrel"
# "winter,rodent,tree,nuts,store""
# "mushroom"
# "fungus,outside,grow,truffles,cream""
# "Princeton"
# "Yale,New Jersey,University,Harvard,Ivy""
# "fire"
# "light,smoke,burn,chimney,cook""
# "wounds"
# "injury,patches,skin,licked,open""
# "latitude"
# "location,lines,parallel,equator,longitude""
# "mail"
# "envelope,letter,postal,send,emails""
# "overdose"
# "suicide,hospital,dose,death,drug""
# "ruby"
# "crystal,red,stone,color,gem""
# "volunteer"
# "work,paid,freely,willingly,service""
# "trojan"
# "condom,horse,achilles,troy,ancient""
# "soccer"
# "goal,game,sport,ball,feet,football""
# "laser"
# "radiation,surgery,Austin Powers,pointer,light""
# "ventriloquism"
# "dummy,pretend,puppet,voice,talk""
# "vanilla"
# "ice cream,beans,chocolate,extract,flavor""
# "restaurant"
# "checks,menu,diner,eat,food""
# "gem"
# "shiny,jewlery,pearl,stone,emerald""
# "karate"
# "punch,kick,martial arts,black,belt""
# "calcium"
# "diet,break,strong,bones,milk""
# "leprosy"
# "quarantine,infection,disfigurement,disease,skin""
# "newspaper"
# "daily,periodical,paper,news,printed""
# "comedian"
# "laugh,funny,jokes,comic,entertainer""
# "voice"
# "tone,sound,speak,hear,sing""
# "skirts"
# "short,girls,women,waist,around""
# "canal"
# "passageway,water,root,Panama,lock""
# "swim"
# "breaststroke,dive,walk,pool,water""
# "vest"
# "denim,suit,waistcoat,clothing,cummerbund""
# "pyramid"
# "building,triangle,Las Vegas,Giza,Egypt""
# "alcoholic"
# "drinking,wet,bar,wine,beer,addiction""
# "pool"
# "backyard,diving board,house,swim,water""
# "sushi"
# "food,rolls,raw,japanese,fish""
# "purse"
# "cash,wallet,bag,woman,money""
# "telephone"
# "ring,dial,hang,mobile,call""
# "rooster"
# "chicken,cock,bird,daybreak,morning""
# "Amsterdam"
# "port,financial,city,Netherlands,weed""
# "crystals"
# "clear,glass,diamond,transparent,hard""
# "fame"
# "hollywood,famous,star,fifteen minutes,rich""
# "aches"
# "dull,continuous,intensity,heart,hurt,pain""
# "synagogue"
# "church,congregation,jewish,assembly,sin""
# "highlighter"
# "text,reading,school,marker,yellow""
# "vending machine"
# "automatic,number,slot,candy,coins""
# "jewel"
# "ornament,crown,gem,precious,stone""
# "lava"
# "Hawaii,magma,hot,erupt,volcano""
# "macaroni"
# "short,tubes,Kraft,pasta,cheese""
# "babies"
# "infants,bottles,loved,born,young""
# "inch"
# "centimeter,foot,imperial,metric,distance,measurement""
# "vegetable"
# "health,diet,pyramid,food,fruit""
# "satellite"
# "earth,orbit,moon,space,sky""
# "literature"
# "classical,art,humanity,books,reading""
# "snail"
# "mollusk,spiral,slug,shell,slow""
# "nest"
# "tree,chicks,eggs,bird,home""
# "rain"
# "falls,water,weather,drizzle,precipitation""
# "sauna"
# "sweating,pool,session,air,heat""
# "suburb"
# "countryside,family,outside,city,soccer man""
# "waterfall"
# "precipice,Niagra,cascade,fall,water""
# "advertisement"
# "adblock,tv,commercial,billboard,notice""
# "Harry Truman"
# "atomic,doctrine,Roosevelt,war,president""
# "lemon"
# "yellow,fruit,citrus,juice,sour""
# "whale"
# "fish,ocean,blowhole,spout,beach""
# "magician"
# "trick,wizard,hat,wand,rabbit""
# "mosaic"
# "ancient,tiles,colors,pattern,art""
# "diabetes"
# "shots,sweet,metabolic,insulin,cure""
# "theater"
# "film,play,seats,theatre,movie""
# "lunch"
# "midday,meal,breakfast,dinner,eat""
# "floor"
# "tile,beneath,ceiling,ground,carpet""
# "immigrant"
# "person,foreign,migrate,live,illegal""
# "massage"
# "body,hands,stroke,rubbing,kneading""
# "mother"
# "birth,parents,dad,mom,father""
# "anchorman"
# "radio,program,anchor,news,tv,movie""
# "taxi"
# "fare,drive,car,driver,passenger""
# "summer"
# "july,warm,winter,fall,spring,season""
# "indigo"
# "dye,plant,color,bunting,blue""
# "traditions"
# "always,holidays,family,year,annual""
# "camel"
# "water,llama,long,desert,humps""
# "money"
# "dollars,bank,change,cash,pay""
# "restrooms"
# "pee,public,room,bathroom,toilet""
# "hallucinations"
# "drugs,experience,LSD,perception,hallucinogens,trip""
# "integer"
# "fraction,whole number,unit,number,composite""
# "glue"
# "craft,gun,eat,adhesive,Elmers""
# "web"
# "cobbwebb,insects,spider,world wide,internet""
# "rose"
# "garden,shrub,thorns,red,flower""
# "photons"
# "sun,energy,laser,radiation,light""
# "Friday"
# "weekend,thursday,saturday,day,week""
# "sky"
# "high,atmosphere,blue,heaven,clouds""
# "lake"
# "pond,Great Lakes,sea,ocean,water""
# "pharmacy"
# "pills,drugstore,medicine,drugs,corner""
# "hay"
# "grazing,crop,bale,horse,farm""
# "narcolepsy"
# "tired,nap,disease,sudden,sleep""
# "prison"
# "crime,sentence,cage,maximum security,jail""
# "basketball"
# "sport,ball,court,nba,hoop""
# "feminism"
# "politics,literature,rights,equality,women""
# "raven"
# "dark,crow,bird,poem,black""
# "viking"
# "Iceland,Norse,Minnesota,Danish,pirates""
# "Island"
# "Hawaii,sea,ground,ocean,land,water""
# "mop"
# "water,floor,wash,broom,clean""
# "vulture"
# "circle,dead,prey,bird,kill""
# "tropics"
# "hot,rainforest,jungle,palm,cancer""
# "traffic"
# "authority,slow,cars,report,jam""
# "knot"
# "nautical mile,secure,wire,shoelace,tie""
# "vacuum"
# "mop,electric,clean,broom,sucking""
# "judge"
# "Supreme Court,lawyer,judgments,decision,court""
# "cape"
# "super hero,weather,Batman,clothing,wear""
# "shadow"
# "shade,cast,project,dark,follow,sun""
# "password"
# "computer,login,security,key,word""
# "sandals"
# "flip-flop,straps,toes,shoes,feet""
# "fleas"
# "parasite,blood,pets,cat,bite,dog""
# "puppy"
# "kitten,pet,young,baby,dog""
# "towel"
# "shower,bath,swimming,dry,white,throw""
# "postcard"
# "travel,abroad,envelope,mail,photo""
# "sofa"
# "living room,sleep,loveseat,rest,couch""
# "twin"
# "siblings,born,pair,birth,identical""
# "clown"
# "party,costume,circus,comic,scary""
# "pimple"
# "head,pop,pus,skin,infection""
# "ozone"
# "oxygen,sun,ultraviolet,sky,atmosphere""
# "garage"
# "covered,house,vehicle,park,car""
# "mosquito"
# "suck,summer,bite,blood,insect""
# "night"
# "moon,dark,watch,day,sleep""
# "heel"
# "sole,ground,wedge,shoe,flat""
# "kaleidoscope"
# "mirrors,patterns,colors,changing,tube,whirl""
# "Mayan"
# "South America,native,mexico,Incas,pyramid""
# "crown"
# "hat,head,queen,king,jewels""
# "yolk"
# "sunny side,embryo,egg,yellow,white""
# "sponge"
# "water,dishes,mops,porous,clean""
# "lobster"
# "sea,food,pincers,red,crustacean""
# "Somalia"
# "country,pirates,republic,horn,Africa""
# "home"
# "love,family,live,house,house""
# "twig"
# "shrub,tree,stem,branch,wood""
# "leaf"
# "spring,color,turn,fall,green,tree""
# "paleolithic"
# "age,stone,ago,period,years""
# "pet"
# "animal,adopt,cat,rabbit,dog""
# "noon"
# "morning,12,afternoon,midnight,time""
# "ice"
# "water,cold,slide,frozen,snow""
# "rhino"
# "animal,grey,elephant,Africa,horn""
# "religion"
# "deity,Christianity,god,worship,belief""
# "fog"
# "mist,see,gas,water vapor,smoke""
# "inflammation"
# "injury,illness,tissue,swelling,irritation""
# "juices"
# "food,orange,cup,fruit,vegetables""
# "heir"
# "princess,throne,prince,king,inherit""
# "convict"
# "jail,guilty,criminal,offense,crime""
# "forks"
# "four,eating,utencils,spoons,knives""
# "epic"
# "muses,heroic,beowulf,poem,book""
# "knife"
# "cutting,eating,utencil,spoon,fork""
# "nose"
# "face,sniff,bleed,blowing,smell""
# "pepper"
# "shaker,salt,taste,spice,season""
# "hose"
# "firetruck,nozzle,firefighting,water,flush""
# "energy"
# "electricity,geothermal,wind,nuclear,thermodynamic""
# "rum"
# "molasses,spirit,liquor,alcohol,vodka""
# "salmon"
# "roll,bear,pink,trout,fish""
# "corn"
# "farm,cereal,cob,field,grain""
# "rug"
# "ground,floor,floor,area,carpet""
# "cork"
# "bark,tree,wine,wood,float""
# "devil"
# "demon,evil,soul,imp,hell""
# "vault"
# "lock,safe,arch,room,bank""
# "abroad"
# "home,roamed,export,walking,travel,imports""
# "zoo"
# "care,cages,public,conservation,animals""
# "cowboy"
# "ranch,mexico,boots,western,rodeo,hats""
# "universe"
# "world,alternative,stars,space,galaxy""
# "abstinence"
# "control,restraint,alcohol,drugs,sex""
# "numerator"
# "integer,denominator,fraction,top,number""
# "virus"
# "antibodies,bacteria,sick,bug,infection""
# "oatmeal"
# "porridge,brown sugar,Quaker,cereal,breakfast""
# "ounce"
# "weight,grams,measurement,unit,pound""
# "sweat"
# "wet,exercise,skin,heat,pig""
# "neighbor"
# "near,live,next,home,house""
# "tongue"
# "whistle,speaking,taste,lick,mouth""
# "octopus"
# "squid,sea,tentacles,arms,ink""
# "sweater"
# "hoodie,clothing,cashmere,dress,wool""
# "emcee"
# "occasion,perform,entertainment,ceremonies,master,host""
# "garbage"
# "waste,recycling,throw out,curb,trash""
# "librarians"
# "borrow,administers,study,books,library""
# "homeless"
# "beg,shelter,cardboard box,live,street""
# "sunglasses"
# "wear,UV,glasses,shades,sun""
# "yawn"
# "mouth,inhale,tiredness,wide,open""
# "panorama"
# "camera,art,view,wide,photo""
# "museum"
# "Louvre,tour,pieces,art,exhibit""
# "tennis"
# "sport,game,ball,serve,return""
# "sock"
# "toes,barefoot,stocking,shoes,feet""
# "reindeer"
# "Rudolph,sleigh,deer,Christmas,Santa""
# "virgin"
# "never,cherry,olive,Mary,sex""
# "refrigerator"
# "cold,freezer,food,cool,chill""
# "dynamite"
# "TNT,reaction,explosion,stick,nitroglycerin""
# "fish"
# "water,catch,bait,net,sea""
# "mountains"
# "altitude,Alps,Rocky,valley,snow""
# "receipt"
# "goods,pay,check,paper,buy""
# "north"
# "cardinal,west,east,south,direction""
# "sundaes"
# "chocolate,nuts,syrup,dessert,ice cream""
# "fireworks"
# "rockets,4th of July,celebrations,sky,colors""
# "hiccup"
# "stop,diaphragm,sound,cough,drunk""
# "atom"
# "protons,electrons,nuclear,small,molecule""
# "mice"
# "pest,mouse,men,cat,experiments""
# "corduroy"
# "ribs,fabric,bear,pants,cords""
# "penguin"
# "flipper,white,black,slide,bird,Antartica""
# "waffles"
# "Belgian,iron,house,breakfast,pancakes""
# "skull"
# "bone,skeleton,cranium,head,brain""
# "Camelot"
# "Excalibur,knights,court,king,Arthur""
# "peso"
# "Spanish,currency,mexico,dollar,money""
# "whiskey"
# "sour,distilled,alcohol,liquor,rye""
# "dvd"
# "tv,movie,disc,cd,burn""
# "zodiac"
# "calendar,astronomy,constellations,astrology,signs""
# "grass"
# "patch,green,plant,grazing,yard""
# "condiment"
# "ketchup,relishes,pepper,mustard,jelly""
# "email"
# "internet,gmail,electronic,sending,message,mail""
# "menstruation"
# "PMS,month,blood,menopause,cramp""
# "CIA"
# "FBI,Central Intelligence Agency,United States,spy,federal""
# "medication"
# "doctor,drug,health,treatment,sick""
# "whisper"
# "loud,speeking,confidential,softly,telephone""
# "umpire"
# "safe,ball,stike,call,baseball""
# "circus"
# "performers,acrobats,clowns,freak,tents""
# "deer"
# "antlers,Bamby,doe,animal,bucks""
# "pie"
# "tin,blueberry,apple,slices,bake""
# "textbook"
# "read,text,book,rent,school""
# "thanksgiving"
# "pilgrims,November,gravy,turkey,holiday""
# "referee"
# "black,whistle,foul,soccer,sports""
# "logo"
# "brand,image,company,design,words""
# "politics"
# "Democracy,Republican,parties,government,power""
# "ship"
# "car,ocean,sea,boat,sail""
# "rainbow"
# "spectrum,arc,sky,hues,color""
# "spice"
# "life,cooking,ginger,flavor,pepper""
# "yoga"
# "pants,hindu,stretch,meditation,spiritual""
# "Mayflower"
# "ship,founding,United States,America,pilgrims""
# "glacier"
# "ice,Titantic,poles,Alaska,iceberg""
# "periodic table"
# "atomic,mass,protons,chemistry,elements""
# "peace"
# "country,time,fight,Nobel,war""
# "forests"
# "woods,green,wildlife,area,trees""
# "astronaut"
# "space,NASA,spacecraft,travel,John Glenn""
# "agoraphobia"
# "alone,crowded,places,irrational,spaces""
# "income"
# "job,earnings,revenue,wage,money""
# "electrons"
# "neutrons,atoms,electricity,protons,orbitals""
# "trash"
# "recycling,bin,throw,hauling,can""
# "aunt"
# "female,sibling,mother,uncle,family""
# "star"
# "night,constellation,sun,orbit,sky""
# "mustard"
# "paste,hot dog,plant,condiment,yellow""
# "vocabulary"
# "understand,speak,know,language,words""
# "toad"
# "hop,lily pads,legs,warts,frog""
# "tablespoon"
# "volume,cup,measurement,cooking,teaspoon""
# "gynecologist"
# "female,women,inspection,doctor,vagina""
# "ovaries"
# "uterus,eggs,sex,testicles,women""
# "tabloid"
# "celebrities,paparazzi,photos,sensational,newspaper""
# "insect"
# "bug,crawl,small,wasps,spider""
# "Tibet"
# "selfimmolation,free,Dali Lama,monk,chinese""
# "velocity"
# "physics,light,acceleration,direction,speed""
# "CNN"
# "national,news,TV,cable,network""
# "sneeze"
# "nose,air,snot,blow,nose""
# "desert"
# "water,sahara,hot,cactus,sand""
# "vein"
# "cardiovascular,red,flow,vessel,blood""
# "ghost"
# "supernatural,spirit,haunted,clear,Casper""
# "contraceptive"
# "pregnancy,baby,prevent,condom,pill""
# "skunk"
# "white,black,striped,spray,smell,weasel""
# "Ferrari"
# "Italy,company,car,designer,enzo""
# "phone"
# "talk,ring,landline,mobile,call""
# "painting"
# "sculpture,museum,picture,landscape,art""
# "groom"
# "proposed,man,marriage,bride,wedding""
# "yacht"
# "sail,club,rich,cruise,boat""
# "orbit"
# "revolution,moon,space,move,planet,around""
# "summit"
# "climb,point,highest,top,mountain""
# "watercolors"
# "fluid,specialty,art,color,paint""
# "teeth"
# "incisor,molars,white,bite,mouth""
# "uterus"
# "womb,menstruation,period,fetus,baby""
# "paramedic"
# "emergency,CPR,hospital,physician,ambulance""
